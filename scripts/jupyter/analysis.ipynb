# %% [markdown]
# # Higgs Boson Machine Learning Classification

# %%
#Let's import some basic modules:
import numpy as np
import pandas as pd
pd.options.display.max_columns = None #this lets pandas show all columns instead of '...'
from matplotlib import pyplot as plt

#Now import two of my functions (see their definition into the "Reference guides" folder):
from AMS_functions import NN_output_to_AMS, plot_AMS
from Plot_distributions import plot_distributions, plot_distributions_final

# %% [markdown]
# ## Let's have a look at the dataset

# %%
data_full = pd.read_csv('dataset_higgs_challenge.csv')

# %% [markdown]
# This Set contains the following subsets, indexed by the `KaggleSet`variable:
# +  `t`: Training,
# + `b`: Public Leaderboard,
# + `v`: Privateleaderboard,
# + `u`: Unused.
#
# For this classification I used only yhe "t" (training data), "b" (validation data) and "v" (test data) set of variables.

# %%
print('Total number of events: ', len(data_full), '\n')
for KaggleSetID in ['t', 'b', 'v', 'u']:
    print('Number of events in the {} KaggleSet: {}'
          .format(KaggleSetID, len(data_full['KaggleSet'][data_full['KaggleSet']==KaggleSetID])))
# Out:
# Total number of events:  818238
#
# Number of events in the t KaggleSet: 250000
# Number of events in the b KaggleSet: 100000
# Number of events in the v KaggleSet: 450000
# Number of events in the u KaggleSet: 18238

# %% [markdown]
# ## Splitting of the data into training, test and validation set and feature engineering
# Within the splitting of the dataset, have been applyied some operations on the engineering of the features for each subset. The problem is that the "phi" variables have a signal distribution that is very similar to the background one. So it's better to consider their linear combination (difference in this case) to make them useful in my classification.
# ### Replace Phi variables by their difference
# + `Delta_phi_tau_lep` = `PRI_tau_phi` - `PRI_lep_phi` (not helpful for 2 jets category)
# + `Delta_phi_met_lep` = `PRI_met_phi` - `PRI_lep_phi`
# + `Delta_phi_jet_jet` = `PRI_jet_leading_phi` - `PRI_jet_subleading_phi`
#     + Drop `PRI_tau_phi`,  `PRI_lep_phi`, `PRI_met_phi`, `PRI_jet_leading_phi` and `PRI_jet_subleading_phi`

# %%
#Let's import my function for the splitting of the dataset into subsets (see its definition into the 
#"Reference guides" folder).
from Splitting_function import splitting

# %%
#Description of the sub-dataset in each line:
#1) Splitting of the dataset into train, test and validation set.
#2) Extracting the weights of the validation and test set.
#3) Extracting the binary arrays for my networks.
#4) Extracting the binary arrays for my BDT

X, df_empty, y_train, y_train_BDT = splitting (data_full, "t")
X_val, weights_val, y_val, y_val_BDT = splitting (data_full, "b")
X_test, weights_test, y_test, y_test_BDT = splitting (data_full, "v")

del(data_full)

# %% [markdown]
# ## I) BDT Classification
# I first will use a BDT model without splitting according to jet number. The class used for this is: `HistGradientBoostingClassifier` from `Sklearn`.

# %%
from sklearn.preprocessing import StandardScaler

#Let's first scale my data.
standard = StandardScaler()
standard.fit(X)
X_standard = standard.transform(X)
X_val_standard = standard.transform(X_val)
X_test_standard = standard.transform(X_test)


from sklearn.experimental import enable_hist_gradient_boosting 
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
BDT = HistGradientBoostingClassifier(max_iter=90, verbose=1, l2_regularization=0.5, learning_rate=.1, max_leaf_nodes=50, 
                                     random_state=45, max_depth=15, max_bins=50)
BDT.fit(X_standard, y_train_BDT)

y_pred_val = BDT.predict_proba(X_val_standard)
y_pred_test = BDT.predict_proba(X_test_standard)

plot_AMS(y_pred_val, y_val, weights_val)
plt.title("Validation Set")
plt.show()
plot_AMS(y_pred_test, y_test, weights_test)
plt.title("Test Set")
plt.show()

plot_distributions(y_pred_val, y_val, 50, weighted=False, weights = None)

del X_standard, X_val_standard, X_test_standard
# Out:
# Binning 0.068 GB of training data: 0.693 s
# Fitting gradient boosted rounds:
# [1/90] 1 tree, 50 leaves, max depth = 9, in 0.083s
# [2/90] 1 tree, 50 leaves, max depth = 9, in 0.067s
# [3/90] 1 tree, 50 leaves, max depth = 9, in 0.066s
# [4/90] 1 tree, 50 leaves, max depth = 9, in 0.071s
# [5/90] 1 tree, 50 leaves, max depth = 9, in 0.062s
# [6/90] 1 tree, 50 leaves, max depth = 10, in 0.062s
# [7/90] 1 tree, 50 leaves, max depth = 10, in 0.065s
# [8/90] 1 tree, 50 leaves, max depth = 10, in 0.058s
# [9/90] 1 tree, 50 leaves, max depth = 9, in 0.064s
# [10/90] 1 tree, 50 leaves, max depth = 11, in 0.060s
# [11/90] 1 tree, 50 leaves, max depth = 10, in 0.057s
# [12/90] 1 tree, 50 leaves, max depth = 13, in 0.065s
# [13/90] 1 tree, 50 leaves, max depth = 9, in 0.063s
# [14/90] 1 tree, 50 leaves, max depth = 14, in 0.061s
# [15/90] 1 tree, 50 leaves, max depth = 9, in 0.061s
# [16/90] 1 tree, 50 leaves, max depth = 10, in 0.061s
# [17/90] 1 tree, 50 leaves, max depth = 12, in 0.061s
# [18/90] 1 tree, 50 leaves, max depth = 12, in 0.058s
# [19/90] 1 tree, 50 leaves, max depth = 12, in 0.064s
# [20/90] 1 tree, 50 leaves, max depth = 14, in 0.055s
# [21/90] 1 tree, 50 leaves, max depth = 8, in 0.065s
# [22/90] 1 tree, 50 leaves, max depth = 14, in 0.062s
# [23/90] 1 tree, 50 leaves, max depth = 10, in 0.063s
# [24/90] 1 tree, 50 leaves, max depth = 14, in 0.056s
# [25/90] 1 tree, 50 leaves, max depth = 12, in 0.063s
# [26/90] 1 tree, 50 leaves, max depth = 13, in 0.056s
# [27/90] 1 tree, 50 leaves, max depth = 15, in 0.058s
# [28/90] 1 tree, 50 leaves, max depth = 11, in 0.057s
# [29/90] 1 tree, 50 leaves, max depth = 11, in 0.061s
# [30/90] 1 tree, 50 leaves, max depth = 12, in 0.056s
# [31/90] 1 tree, 50 leaves, max depth = 15, in 0.062s
# [32/90] 1 tree, 50 leaves, max depth = 14, in 0.064s
# [33/90] 1 tree, 50 leaves, max depth = 13, in 0.054s
# [34/90] 1 tree, 2288 leaves, max depth = 15, in 0.454s
# [35/90] 1 tree, 50 leaves, max depth = 13, in 0.059s
# [36/90] 1 tree, 50 leaves, max depth = 11, in 0.056s
# [37/90] 1 tree, 50 leaves, max depth = 13, in 0.059s
# [38/90] 1 tree, 50 leaves, max depth = 15, in 0.056s
# [39/90] 1 tree, 50 leaves, max depth = 13, in 0.058s
# [40/90] 1 tree, 50 leaves, max depth = 15, in 0.058s
# [41/90] 1 tree, 50 leaves, max depth = 12, in 0.060s
# [42/90] 1 tree, 50 leaves, max depth = 15, in 0.055s
# [43/90] 1 tree, 50 leaves, max depth = 15, in 0.056s
# [44/90] 1 tree, 50 leaves, max depth = 15, in 0.054s
# [45/90] 1 tree, 50 leaves, max depth = 11, in 0.058s
# [46/90] 1 tree, 50 leaves, max depth = 12, in 0.057s
# [47/90] 1 tree, 50 leaves, max depth = 14, in 0.053s
# [48/90] 1 tree, 50 leaves, max depth = 11, in 0.053s
# [49/90] 1 tree, 50 leaves, max depth = 12, in 0.060s
# [50/90] 1 tree, 50 leaves, max depth = 13, in 0.057s
# [51/90] 1 tree, 50 leaves, max depth = 15, in 0.055s
# [52/90] 1 tree, 50 leaves, max depth = 15, in 0.054s
# [53/90] 1 tree, 50 leaves, max depth = 13, in 0.063s
# [54/90] 1 tree, 50 leaves, max depth = 13, in 0.053s
# [55/90] 1 tree, 50 leaves, max depth = 10, in 0.056s
# [56/90] 1 tree, 50 leaves, max depth = 13, in 0.056s
# [57/90] 1 tree, 50 leaves, max depth = 14, in 0.052s
# [58/90] 1 tree, 50 leaves, max depth = 15, in 0.060s
# [59/90] 1 tree, 50 leaves, max depth = 13, in 0.054s
# [60/90] 1 tree, 50 leaves, max depth = 11, in 0.052s
# [61/90] 1 tree, 50 leaves, max depth = 15, in 0.055s
# [62/90] 1 tree, 50 leaves, max depth = 14, in 0.055s
# [63/90] 1 tree, 50 leaves, max depth = 15, in 0.046s
# [64/90] 1 tree, 50 leaves, max depth = 12, in 0.063s
# [65/90] 1 tree, 50 leaves, max depth = 13, in 0.052s
# [66/90] 1 tree, 50 leaves, max depth = 14, in 0.052s
# [67/90] 1 tree, 2419 leaves, max depth = 15, in 0.419s
# [68/90] 1 tree, 50 leaves, max depth = 14, in 0.049s
# [69/90] 1 tree, 50 leaves, max depth = 12, in 0.054s
# [70/90] 1 tree, 50 leaves, max depth = 15, in 0.048s
# [71/90] 1 tree, 50 leaves, max depth = 13, in 0.058s
# [72/90] 1 tree, 50 leaves, max depth = 15, in 0.049s
# [73/90] 1 tree, 50 leaves, max depth = 13, in 0.051s
# [74/90] 1 tree, 1308 leaves, max depth = 15, in 0.261s
# [75/90] 1 tree, 50 leaves, max depth = 11, in 0.052s
# [76/90] 1 tree, 50 leaves, max depth = 15, in 0.049s
# [77/90] 1 tree, 50 leaves, max depth = 11, in 0.053s
# [78/90] 1 tree, 50 leaves, max depth = 10, in 0.054s
# [79/90] 1 tree, 50 leaves, max depth = 10, in 0.042s
# [80/90] 1 tree, 50 leaves, max depth = 12, in 0.054s
# [81/90] 1 tree, 50 leaves, max depth = 12, in 0.049s
# [82/90] 1 tree, 50 leaves, max depth = 12, in 0.043s
# [83/90] 1 tree, 50 leaves, max depth = 14, in 0.039s
# [84/90] 1 tree, 50 leaves, max depth = 12, in 0.055s
# [85/90] 1 tree, 50 leaves, max depth = 10, in 0.039s
# [86/90] 1 tree, 50 leaves, max depth = 11, in 0.053s
# [87/90] 1 tree, 50 leaves, max depth = 13, in 0.037s
# [88/90] 1 tree, 50 leaves, max depth = 13, in 0.044s
# [89/90] 1 tree, 50 leaves, max depth = 12, in 0.057s
# [90/90] 1 tree, 50 leaves, max depth = 14, in 0.036s
# Fit 90 trees in 6.904 s, (10365 total leaves)
# Time spent computing histograms: 2.419s
# Time spent finding best splits:  0.295s
# Time spent applying splits:      1.045s
# Time spent predicting:           0.094s
# The best AMS Score is 3.555 at a Cut Parameter of 0.84
# The best AMS Score is 3.578 at a Cut Parameter of 0.83

# %% [markdown]
# I will split the results just to be able to combine them with the DNN result later

# %%
BDT_0jets_val = y_pred_val[ X_val['PRI_jet_num']==0 ]
BDT_1jet_val = y_pred_val[ X_val['PRI_jet_num']==1 ]
BDT_2jets_val = y_pred_val[ X_val['PRI_jet_num']>=2 ]

y_pred_BDT_val = np.concatenate((BDT_0jets_val, BDT_1jet_val, BDT_2jets_val))

BDT_0jets_test = y_pred_test[ X_test['PRI_jet_num']==0 ]
BDT_1jet_test = y_pred_test[ X_test['PRI_jet_num']==1 ]
BDT_2jets_test = y_pred_test[ X_test['PRI_jet_num']>=2 ]

y_pred_BDT_test = np.concatenate((BDT_0jets_test, BDT_1jet_test, BDT_2jets_test))

# %% [markdown]
# ## II) DNN Classification
# ### Build subsets according to the number of jets because of the different event topologies
#
# Since the BDT model seems to work better without dropping the features and the DNN seems to work better after dropping, I put this here.
#
# Moreover, the HistBDT can handle these -999 values very well, but for the DNN it helped to set them to the mean.
#
# Now I have to construct three subsets according to the number of jets:
# + 0 jets.
# + 1 jet.
# +  \>= 2 jets.
#
# I drop the features in which I have a value equal to -999.

# %%
#Now import one of my functions (see their definition into the "Reference guides" folder):
from Splitting_jets_function import splitting_jets, preprocessing_function

# %%
#Let's construct the data for the case with 0 jets.
X_0jets, y_train_0jets, empty_0 = splitting_jets(X, y_train, df_empty, 0)
X_val_0jets, y_val_0jets, weights_0jets_val = splitting_jets(X_val, y_val, weights_val, 0)
X_test_0jets, y_test_0jets, weights_0jets_test = splitting_jets(X_test, y_test, weights_test, 0)

#Let's construct the data for the case with 1 jets.
X_1jet, y_train_1jet, empty_1 = splitting_jets(X, y_train, df_empty, 1)
X_val_1jet, y_val_1jet, weights_1jet_val = splitting_jets(X_val, y_val, weights_val, 1)
X_test_1jet, y_test_1jet, weights_1jet_test = splitting_jets(X_test, y_test, weights_test, 1)

#Let's construct the data for the case with 2 jets.
X_2jets, y_train_2jets, empty_2 = splitting_jets(X, y_train, df_empty, 2)
X_val_2jets, y_val_2jets, weights_2jets_val = splitting_jets(X_val, y_val, weights_val, 2)
X_test_2jets, y_test_2jets, weights_2jets_test = splitting_jets(X_test, y_test, weights_test, 2)

del empty_0, empty_1, empty_2
# Out:
# /home/gianluca/Splitting_jets_function.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['DER_mass_MMC'][subset['DER_mass_MMC']==-999.] = np.mean(subset['DER_mass_MMC'][subset['DER_mass_MMC']!=-999.])
# /home/gianluca/Splitting_jets_function.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   weights_jets = weights[Subset['PRI_jet_num']==0 ].reset_index(drop=True)
# /home/gianluca/Splitting_jets_function.py:49: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   weights_jets = weights[Subset['PRI_jet_num']==1 ].reset_index(drop=True)
# /home/gianluca/Splitting_jets_function.py:55: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   weights_jets = weights[Subset['PRI_jet_num']>=2 ].reset_index(drop=True)

# %% [markdown]
# ### Lets plot some of the new features
# Let's verify now if my features given by the linear combination of "phi" variables are good for the classification.

# %%
a1 = X_0jets['Delta_phi_tau_lep']
a2 = X_0jets['Delta_phi_met_lep']
a3 = X_0jets['Delta_eta_tau_lep']
a4 = X_2jets['Delta_phi_jet_jet']

fig, ax = plt.subplots(2,2, figsize=(10,8), sharex=True)

ax[0,0].hist(a1[y_train_0jets[:,0]==1], density=True, histtype='step', bins=20, label='Background')
ax[0,0].hist(a1[y_train_0jets[:,0]==0], density=True, histtype='step', bins=20, label='Signal')
ax[0,0].set_title('Delta phi tau lep (0 jets)', fontsize=15)
ax[0,0].set_ylabel('Density')

ax[0,1].hist(a2[y_train_0jets[:,0]==1], density=True, histtype='step', bins=20, label='Background')
ax[0,1].hist(a2[y_train_0jets[:,0]==0], density=True, histtype='step', bins=20, label='Signal')
ax[0,1].set_title('Delta phi met lep (0 jets)', fontsize=15)

ax[1,0].hist(a3[y_train_0jets[:,0]==1], density=True, histtype='step', bins=20, label='Background')
ax[1,0].hist(a3[y_train_0jets[:,0]==0], density=True, histtype='step', bins=20, label='Signal')
ax[1,0].set_title('Delta eta tau lep (0 jets)', fontsize=15)
ax[1,0].set_ylabel('Density')

ax[1,1].hist(a4[y_train_2jets[:,0]==1], density=True, histtype='step', bins=20, label='Background')
ax[1,1].hist(a4[y_train_2jets[:,0]==0], density=True, histtype='step', bins=20, label='Signal')
ax[1,1].set_title('Delta phi jet jet (2 jets)', fontsize=15)

plt.suptitle('Distributions of the new variables', fontsize=25)
ax[0,0].legend()
ax[0,1].legend()
ax[1,0].legend()
ax[1,1].legend()


#plt.savefig('new_variables.png', dpi=300)

del a1, a2, a3, a4

# %% [markdown]
# ### Import some other functions
# I used the library "keras" for the construction of my DNN.

# %%
from sklearn.preprocessing import StandardScaler #This is the best one.

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.regularizers import l1, l2
from keras.callbacks.callbacks import EarlyStopping

#Let's import my function for the construction of my model (see its definition into the "Reference guides" folder):
from Make_model import make_model
# Out:
# Using TensorFlow backend.
# /home/gianluca/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/gianluca/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## 2-jets Classification

# %% [markdown]
# I first started scaling my data.

# %%
standard_2jets = StandardScaler()
standard_2jets.fit(X_2jets)
X_2jets_standard = standard_2jets.transform(X_2jets)
X_val_2jets_standard = standard_2jets.transform(X_val_2jets)
X_test_2jets_standard = standard_2jets.transform(X_test_2jets)

# %% [markdown]
# Now let's perform a DNN

# %%
np.random.seed(42)
DNN_2jets = make_model([64, 128, 64, 64, 32, 8], 'relu', 0.1, 'Adam', 'L2', 0.0001, X_2jets.shape[-1])

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

history = DNN_2jets.fit(X_2jets_standard, y_train_2jets, batch_size=256, epochs=50, verbose=1, 
                  validation_data=(X_val_2jets_standard, y_val_2jets), callbacks = [early_stopping], class_weight = None)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='lower right')
plt.show()

y_pred_2jets_val = DNN_2jets.predict(X_val_2jets_standard)
y_pred_2jets_test = DNN_2jets.predict(X_test_2jets_standard)
plot_AMS(y_pred_2jets_val, y_val_2jets, weights_2jets_val)
plt.show()
plt.grid()
plot_AMS(y_pred_2jets_test, y_test_2jets, weights_2jets_test)
plt.grid()
# Out:
# WARNING:tensorflow:From /home/gianluca/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/gianluca/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 72543 samples, validate on 29046 samples
# Epoch 1/50
# 72543/72543 [==============================] - 2s 34us/step - loss: 0.4796 - accuracy: 0.7918 - val_loss: 0.3998 - val_accuracy: 0.8368
# Epoch 2/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.4062 - accuracy: 0.8381 - val_loss: 0.3844 - val_accuracy: 0.8432
# Epoch 3/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3907 - accuracy: 0.8437 - val_loss: 0.3810 - val_accuracy: 0.8425
# Epoch 4/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3820 - accuracy: 0.8476 - val_loss: 0.3750 - val_accuracy: 0.8462
# Epoch 5/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3752 - accuracy: 0.8485 - val_loss: 0.3707 - val_accuracy: 0.8487
# Epoch 6/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3704 - accuracy: 0.8509 - val_loss: 0.3664 - val_accuracy: 0.8516
# Epoch 7/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.3667 - accuracy: 0.8521 - val_loss: 0.3640 - val_accuracy: 0.8507
# Epoch 8/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.3611 - accuracy: 0.8532 - val_loss: 0.3659 - val_accuracy: 0.8518
# Epoch 9/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.3606 - accuracy: 0.8530 - val_loss: 0.3624 - val_accuracy: 0.8526
# Epoch 10/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3567 - accuracy: 0.8538 - val_loss: 0.3622 - val_accuracy: 0.8505
# Epoch 11/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3536 - accuracy: 0.8558 - val_loss: 0.3612 - val_accuracy: 0.8501
# Epoch 12/50
# 72543/72543 [==============================] - 2s 21us/step - loss: 0.3526 - accuracy: 0.8563 - val_loss: 0.3585 - val_accuracy: 0.8510
# Epoch 13/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.3502 - accuracy: 0.8565 - val_loss: 0.3628 - val_accuracy: 0.8493
# Epoch 14/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.3480 - accuracy: 0.8591 - val_loss: 0.3578 - val_accuracy: 0.8509
# Epoch 15/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3468 - accuracy: 0.8587 - val_loss: 0.3658 - val_accuracy: 0.8466
# Epoch 16/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.3447 - accuracy: 0.8602 - val_loss: 0.3576 - val_accuracy: 0.8509
# Epoch 17/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3434 - accuracy: 0.8613 - val_loss: 0.3583 - val_accuracy: 0.8512
# Epoch 18/50
# 72543/72543 [==============================] - 2s 23us/step - loss: 0.3424 - accuracy: 0.8610 - val_loss: 0.3636 - val_accuracy: 0.8501
# Epoch 19/50
# 72543/72543 [==============================] - 2s 24us/step - loss: 0.3399 - accuracy: 0.8622 - val_loss: 0.3605 - val_accuracy: 0.8509
# The best AMS Score is 2.785 at a Cut Parameter of 0.97
# The best AMS Score is 2.407 at a Cut Parameter of 0.96

# %%
del X_2jets_standard, X_val_2jets_standard, X_2jets, X_val_2jets, X_test_2jets_standard, X_test_2jets,

# %% [markdown]
# ## 1-jet Classification
# Now let's do the same with the other subsets.

# %%
standard_1jet = StandardScaler()
standard_1jet.fit(X_1jet)
X_1jet_standard = standard_1jet.transform(X_1jet)
X_val_1jet_standard = standard_1jet.transform(X_val_1jet)
X_test_1jet_standard = standard_1jet.transform(X_test_1jet)

# %%
np.random.seed(42)
DNN_1jet = make_model([64, 64, 64, 32, 8], 'relu', 0.1, 'Adagrad', 'L1', 0.0001, X_1jet.shape[-1])

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

history = DNN_1jet.fit(X_1jet_standard, y_train_1jet, batch_size=256, epochs=50, verbose=1, 
                  validation_data=(X_val_1jet_standard, y_val_1jet), callbacks = [early_stopping], class_weight = None)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='lower right')
plt.show()

y_pred_1jet_val = DNN_1jet.predict(X_val_1jet_standard)
y_pred_1jet_test = DNN_1jet.predict(X_test_1jet_standard)
plot_AMS(y_pred_1jet_val, y_val_1jet, weights_1jet_val)
plt.grid()
plt.show()
plot_AMS(y_pred_1jet_test, y_test_1jet, weights_1jet_test)
plt.grid()
# Out:
# Train on 77544 samples, validate on 30791 samples
# Epoch 1/50
# 77544/77544 [==============================] - 2s 21us/step - loss: 0.5736 - accuracy: 0.7878 - val_loss: 0.5176 - val_accuracy: 0.8098
# Epoch 2/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.5212 - accuracy: 0.8103 - val_loss: 0.5005 - val_accuracy: 0.8144
# Epoch 3/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.5075 - accuracy: 0.8129 - val_loss: 0.4915 - val_accuracy: 0.8165
# Epoch 4/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4979 - accuracy: 0.8149 - val_loss: 0.4855 - val_accuracy: 0.8158
# Epoch 5/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4915 - accuracy: 0.8164 - val_loss: 0.4804 - val_accuracy: 0.8174
# Epoch 6/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4860 - accuracy: 0.8176 - val_loss: 0.4754 - val_accuracy: 0.8193
# Epoch 7/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4814 - accuracy: 0.8181 - val_loss: 0.4719 - val_accuracy: 0.8183
# Epoch 8/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4781 - accuracy: 0.8178 - val_loss: 0.4690 - val_accuracy: 0.8200
# Epoch 9/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4755 - accuracy: 0.8190 - val_loss: 0.4670 - val_accuracy: 0.8201
# Epoch 10/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4732 - accuracy: 0.8197 - val_loss: 0.4634 - val_accuracy: 0.8199
# Epoch 11/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4693 - accuracy: 0.8204 - val_loss: 0.4619 - val_accuracy: 0.8206
# Epoch 12/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4671 - accuracy: 0.8205 - val_loss: 0.4598 - val_accuracy: 0.8203
# Epoch 13/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4657 - accuracy: 0.8206 - val_loss: 0.4582 - val_accuracy: 0.8206
# Epoch 14/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4647 - accuracy: 0.8196 - val_loss: 0.4583 - val_accuracy: 0.8202
# Epoch 15/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4624 - accuracy: 0.8205 - val_loss: 0.4560 - val_accuracy: 0.8207
# Epoch 16/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4605 - accuracy: 0.8218 - val_loss: 0.4544 - val_accuracy: 0.8201
# Epoch 17/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4591 - accuracy: 0.8204 - val_loss: 0.4541 - val_accuracy: 0.8208
# Epoch 18/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4579 - accuracy: 0.8218 - val_loss: 0.4521 - val_accuracy: 0.8207
# Epoch 19/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4559 - accuracy: 0.8220 - val_loss: 0.4517 - val_accuracy: 0.8206
# Epoch 20/50
# 77544/77544 [==============================] - 1s 19us/step - loss: 0.4560 - accuracy: 0.8208 - val_loss: 0.4503 - val_accuracy: 0.8206
# Epoch 21/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4539 - accuracy: 0.8208 - val_loss: 0.4495 - val_accuracy: 0.8209
# Epoch 22/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4533 - accuracy: 0.8207 - val_loss: 0.4482 - val_accuracy: 0.8208
# Epoch 23/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4527 - accuracy: 0.8230 - val_loss: 0.4476 - val_accuracy: 0.8212
# Epoch 24/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4528 - accuracy: 0.8216 - val_loss: 0.4471 - val_accuracy: 0.8207
# Epoch 25/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4513 - accuracy: 0.8212 - val_loss: 0.4460 - val_accuracy: 0.8211
# Epoch 26/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4516 - accuracy: 0.8217 - val_loss: 0.4458 - val_accuracy: 0.8213
# Epoch 27/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4497 - accuracy: 0.8216 - val_loss: 0.4453 - val_accuracy: 0.8221
# Epoch 28/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4493 - accuracy: 0.8215 - val_loss: 0.4444 - val_accuracy: 0.8212
# Epoch 29/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4482 - accuracy: 0.8217 - val_loss: 0.4441 - val_accuracy: 0.8209
# Epoch 30/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4461 - accuracy: 0.8237 - val_loss: 0.4443 - val_accuracy: 0.8206
# Epoch 31/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4471 - accuracy: 0.8222 - val_loss: 0.4428 - val_accuracy: 0.8217
# Epoch 32/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4457 - accuracy: 0.8223 - val_loss: 0.4431 - val_accuracy: 0.8210
# Epoch 33/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4455 - accuracy: 0.8226 - val_loss: 0.4418 - val_accuracy: 0.8208
# Epoch 34/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4445 - accuracy: 0.8224 - val_loss: 0.4411 - val_accuracy: 0.8214
# Epoch 35/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4444 - accuracy: 0.8223 - val_loss: 0.4415 - val_accuracy: 0.8215
# Epoch 36/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4436 - accuracy: 0.8229 - val_loss: 0.4413 - val_accuracy: 0.8211
# Epoch 37/50
# 77544/77544 [==============================] - 1s 18us/step - loss: 0.4435 - accuracy: 0.8226 - val_loss: 0.4405 - val_accuracy: 0.8216
# The best AMS Score is 1.642 at a Cut Parameter of 0.86
# The best AMS Score is 1.659 at a Cut Parameter of 0.80

# %%
del X_1jet_standard, X_val_1jet_standard, X_1jet, X_val_1jet,  X_test_1jet_standard, X_test_1jet,

# %% [markdown]
# ## 0-jets Classification

# %%
standard_0jets = StandardScaler()
standard_0jets.fit(X_0jets)
X_0jets_standard = standard_0jets.transform(X_0jets)
X_val_0jets_standard = standard_0jets.transform(X_val_0jets)
X_test_0jets_standard = standard_0jets.transform(X_test_0jets)

# %%
np.random.seed(42)
DNN_0jets = make_model([32, 64, 128, 64, 32, 8], 'elu', 0.1, 'Adagrad', 'L1', 0.0001, X_0jets.shape[-1])

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

history = DNN_0jets.fit(X_0jets_standard, y_train_0jets, batch_size=256, epochs=50, verbose=1, 
                  validation_data=(X_val_0jets_standard, y_val_0jets), callbacks = [early_stopping], class_weight = None)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='lower right')
plt.show()

y_pred_0jets_val = DNN_0jets.predict(X_val_0jets_standard)
y_pred_0jets_test = DNN_0jets.predict(X_test_0jets_standard)
plot_AMS(y_pred_0jets_val, y_val_0jets, weights_0jets_val)
plt.show()
plot_AMS(y_pred_0jets_test, y_test_0jets, weights_0jets_test)
# Out:
# Train on 99913 samples, validate on 40163 samples
# Epoch 1/50
# 99913/99913 [==============================] - 3s 26us/step - loss: 0.5488 - accuracy: 0.8371 - val_loss: 0.5110 - val_accuracy: 0.8429
# Epoch 2/50
# 99913/99913 [==============================] - 2s 25us/step - loss: 0.4997 - accuracy: 0.8432 - val_loss: 0.4820 - val_accuracy: 0.8444
# Epoch 3/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.4755 - accuracy: 0.8437 - val_loss: 0.4619 - val_accuracy: 0.8469
# Epoch 4/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.4583 - accuracy: 0.8456 - val_loss: 0.4499 - val_accuracy: 0.8446
# Epoch 5/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.4459 - accuracy: 0.8456 - val_loss: 0.4386 - val_accuracy: 0.8452
# Epoch 6/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.4355 - accuracy: 0.8461 - val_loss: 0.4319 - val_accuracy: 0.8441
# Epoch 7/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.4288 - accuracy: 0.8466 - val_loss: 0.4243 - val_accuracy: 0.8454
# Epoch 8/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.4226 - accuracy: 0.8468 - val_loss: 0.4187 - val_accuracy: 0.8466
# Epoch 9/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.4190 - accuracy: 0.8462 - val_loss: 0.4142 - val_accuracy: 0.8470
# Epoch 10/50
# 99913/99913 [==============================] - 2s 21us/step - loss: 0.4145 - accuracy: 0.8464 - val_loss: 0.4104 - val_accuracy: 0.8467
# Epoch 11/50
# 99913/99913 [==============================] - 2s 17us/step - loss: 0.4107 - accuracy: 0.8463 - val_loss: 0.4074 - val_accuracy: 0.8469
# Epoch 12/50
# 99913/99913 [==============================] - 2s 17us/step - loss: 0.4072 - accuracy: 0.8468 - val_loss: 0.4065 - val_accuracy: 0.8444
# Epoch 13/50
# 99913/99913 [==============================] - 2s 19us/step - loss: 0.4050 - accuracy: 0.8474 - val_loss: 0.4040 - val_accuracy: 0.8462
# Epoch 14/50
# 99913/99913 [==============================] - 2s 16us/step - loss: 0.4039 - accuracy: 0.8474 - val_loss: 0.4002 - val_accuracy: 0.8467
# Epoch 15/50
# 99913/99913 [==============================] - 2s 17us/step - loss: 0.4008 - accuracy: 0.8470 - val_loss: 0.3988 - val_accuracy: 0.8464
# Epoch 16/50
# 99913/99913 [==============================] - 2s 17us/step - loss: 0.3991 - accuracy: 0.8470 - val_loss: 0.3969 - val_accuracy: 0.8470
# Epoch 17/50
# 99913/99913 [==============================] - 2s 16us/step - loss: 0.3979 - accuracy: 0.8473 - val_loss: 0.3972 - val_accuracy: 0.8442
# Epoch 18/50
# 99913/99913 [==============================] - 2s 18us/step - loss: 0.3956 - accuracy: 0.8473 - val_loss: 0.3938 - val_accuracy: 0.8474
# Epoch 19/50
# 99913/99913 [==============================] - 2s 15us/step - loss: 0.3948 - accuracy: 0.8480 - val_loss: 0.3929 - val_accuracy: 0.8477
# Epoch 20/50
# 99913/99913 [==============================] - 2s 15us/step - loss: 0.3935 - accuracy: 0.8479 - val_loss: 0.3921 - val_accuracy: 0.8468
# Epoch 21/50
# 99913/99913 [==============================] - 2s 15us/step - loss: 0.3925 - accuracy: 0.8478 - val_loss: 0.3906 - val_accuracy: 0.8466
# Epoch 22/50
# 99913/99913 [==============================] - 2s 21us/step - loss: 0.3911 - accuracy: 0.8468 - val_loss: 0.3887 - val_accuracy: 0.8481
# Epoch 23/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3903 - accuracy: 0.8482 - val_loss: 0.3885 - val_accuracy: 0.8474
# Epoch 24/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3899 - accuracy: 0.8472 - val_loss: 0.3876 - val_accuracy: 0.8478
# Epoch 25/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3887 - accuracy: 0.8476 - val_loss: 0.3864 - val_accuracy: 0.8476
# Epoch 26/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3878 - accuracy: 0.8472 - val_loss: 0.3865 - val_accuracy: 0.8468
# Epoch 27/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3872 - accuracy: 0.8479 - val_loss: 0.3848 - val_accuracy: 0.8483
# Epoch 28/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3864 - accuracy: 0.8474 - val_loss: 0.3844 - val_accuracy: 0.8476
# Epoch 29/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3859 - accuracy: 0.8479 - val_loss: 0.3840 - val_accuracy: 0.8486
# Epoch 30/50
# 99913/99913 [==============================] - 2s 23us/step - loss: 0.3854 - accuracy: 0.8477 - val_loss: 0.3835 - val_accuracy: 0.8480
# Epoch 31/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3845 - accuracy: 0.8476 - val_loss: 0.3845 - val_accuracy: 0.8462
# Epoch 32/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3844 - accuracy: 0.8479 - val_loss: 0.3820 - val_accuracy: 0.8486
# Epoch 33/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3837 - accuracy: 0.8482 - val_loss: 0.3817 - val_accuracy: 0.8484
# Epoch 34/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3829 - accuracy: 0.8484 - val_loss: 0.3813 - val_accuracy: 0.8481
# Epoch 35/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3823 - accuracy: 0.8482 - val_loss: 0.3814 - val_accuracy: 0.8473
# Epoch 36/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3821 - accuracy: 0.8484 - val_loss: 0.3801 - val_accuracy: 0.8489
# Epoch 37/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3815 - accuracy: 0.8485 - val_loss: 0.3800 - val_accuracy: 0.8489
# Epoch 38/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3810 - accuracy: 0.8480 - val_loss: 0.3799 - val_accuracy: 0.8483
# Epoch 39/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3806 - accuracy: 0.8484 - val_loss: 0.3792 - val_accuracy: 0.8485
# Epoch 40/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3803 - accuracy: 0.8481 - val_loss: 0.3789 - val_accuracy: 0.8483
# Epoch 41/50
# 99913/99913 [==============================] - 2s 24us/step - loss: 0.3801 - accuracy: 0.8484 - val_loss: 0.3783 - val_accuracy: 0.8489
# Epoch 42/50
# 99913/99913 [==============================] - 2s 23us/step - loss: 0.3806 - accuracy: 0.8478 - val_loss: 0.3793 - val_accuracy: 0.8477
# Epoch 43/50
# 99913/99913 [==============================] - 2s 23us/step - loss: 0.3799 - accuracy: 0.8489 - val_loss: 0.3785 - val_accuracy: 0.8476
# Epoch 44/50
# 99913/99913 [==============================] - 2s 23us/step - loss: 0.3793 - accuracy: 0.8483 - val_loss: 0.3776 - val_accuracy: 0.8488
# Epoch 45/50
# 99913/99913 [==============================] - 2s 23us/step - loss: 0.3797 - accuracy: 0.8482 - val_loss: 0.3771 - val_accuracy: 0.8488
# Epoch 46/50
# 99913/99913 [==============================] - 2s 23us/step - loss: 0.3793 - accuracy: 0.8475 - val_loss: 0.3780 - val_accuracy: 0.8479
# Epoch 47/50
# 99913/99913 [==============================] - 2s 23us/step - loss: 0.3789 - accuracy: 0.8483 - val_loss: 0.3766 - val_accuracy: 0.8486
# The best AMS Score is 2.448 at a Cut Parameter of 0.78
# The best AMS Score is 2.433 at a Cut Parameter of 0.81

# %%
del X_0jets_standard, X_val_0jets_standard, X_0jets, X_val_0jets, X_test_0jets_standard, X_test_0jets,

# %% [markdown]
# ## Total AMS Score from our DNNs
# Total AMS score considering all the AMS of each subset:

# %%
y_pred_DNN_val = np.concatenate((y_pred_0jets_val, y_pred_1jet_val, y_pred_2jets_val))
y_val_total = np.concatenate((y_val_0jets, y_val_1jet, y_val_2jets))
weights_total_val = np.concatenate((weights_0jets_val, weights_1jet_val, weights_2jets_val))

y_pred_DNN_test = np.concatenate((y_pred_0jets_test, y_pred_1jet_test, y_pred_2jets_test))
y_test_total = np.concatenate((y_test_0jets, y_test_1jet, y_test_2jets))
weights_total_test = np.concatenate((weights_0jets_test, weights_1jet_test, weights_2jets_test))

# %%
plot_AMS(y_pred_DNN_val, y_val_total, weights_total_val)
plt.title("Validation Set")
plt.show()
plt.title("Test Set")
plot_AMS(y_pred_DNN_test, y_test_total, weights_total_test)
# Out:
# The best AMS Score is 3.480 at a Cut Parameter of 0.81
# The best AMS Score is 3.529 at a Cut Parameter of 0.83

# %% [markdown]
# ## Combination of both Outputs

# %% [markdown]
# ### The average of both gets a significantly better result!
# I will now try the logistic regression for the combination of the AMS of DDN and BDT.

# %%
from sklearn.linear_model import LogisticRegression
dataset_blend_val = np.append(y_pred_DNN_val[:,1].reshape(-1,1), y_pred_BDT_val[:,1].reshape(-1,1), axis=1)
dataset_blend_test = np.append(y_pred_DNN_test[:,1].reshape(-1,1), y_pred_BDT_test[:,1].reshape(-1,1), axis=1)
blend = LogisticRegression(solver='lbfgs')
blend.fit(dataset_blend_val,  y_val_total[:,1])
blended_val = blend.predict_proba(dataset_blend_val)
blended_test = blend.predict_proba(dataset_blend_test)

# %%
print('DNN:')
plot_AMS(y_pred_DNN_val, y_val_total, weights_total_val)
print('BDT:')
plot_AMS(y_pred_BDT_val, y_val_total, weights_total_val)
print('Combination:')
plot_AMS(blended_val, y_val_total, weights_total_val)
#plot_AMS(blended, y_val_total, weights_total)
plt.legend(['DNN', 'BDT', 'DNN + BDT ave'])
plt.ylim(2.8,)
# Out:
# DNN:
# The best AMS Score is 3.480 at a Cut Parameter of 0.81
# BDT:
# The best AMS Score is 3.555 at a Cut Parameter of 0.84
# Combination:
# The best AMS Score is 3.605 at a Cut Parameter of 0.88
# (2.8, 3.7847524182371086)

# %% [markdown]
# ## Final Result

# %%
print('DNN:')
plot_AMS(y_pred_DNN_test, y_test_total, weights_total_test)
print('BDT:')
plot_AMS(y_pred_BDT_test, y_test_total, weights_total_test)
print('Combination:')
plot_AMS(blended_test, y_test_total, weights_total_test)
#plot_AMS(blended, y_val_total, weights_total)
plt.legend(['DNN', 'BDT', 'DNN + BDT'])
plt.ylim(2.8,)
plt.savefig('AMS_total.png', dpi=300)
# Out:
# DNN:
# The best AMS Score is 3.529 at a Cut Parameter of 0.83
# BDT:
# The best AMS Score is 3.578 at a Cut Parameter of 0.83
# Combination:
# The best AMS Score is 3.652 at a Cut Parameter of 0.88

# %%
plot_distributions_final(blended_val, blended_test, y_val_total, 50, False, weights_total_val, 
                         weights_total_test)
plt.savefig('Final_distribution_unweighted.png', dpi=300)
plt.show()

plot_distributions_final(blended_val, blended_test, y_val_total, 50, True, weights_total_val, 
                         weights_total_test)
plt.savefig('Final_distribution_weighted.png', dpi=300)
